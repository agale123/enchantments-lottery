# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("2022_raw.csv")
df
# Out:
#       Preferred Entry Date 1   Preferred Division 1  \
# 0                   9/2/2022  Core Enchantment Zone
# 1                  8/15/2022          Colchuck Zone
# 2                  8/12/2022              Snow Zone
# 3                  7/12/2022  Core Enchantment Zone
# 4                   9/3/2022           Stuart  Zone
# ...                      ...                    ...
# 36822              6/28/2022  Core Enchantment Zone
# 36823               8/1/2022          Colchuck Zone
# 36824              7/11/2022  Core Enchantment Zone
# 36825              6/24/2022  Core Enchantment Zone
# 36826              8/29/2022  Core Enchantment Zone
#
#        Minimum Acceptable Group Size 1  Maximum Requested Group Size 1  \
# 0                                    8                               8
# 1                                    2                               2
# 2                                    8                               8
# 3                                    2                               2
# 4                                    4                               4
# ...                                ...                             ...
# 36822                                2                               2
# 36823                                8                               8
# 36824                                4                               4
# 36825                                6                               6
# 36826                                8                               8
#
#       Preferred Entry Date 2   Preferred Division 2  \
# 0                  8/26/2022          Colchuck Zone
# 1                  8/24/2022          Colchuck Zone
# 2                  8/19/2022              Snow Zone
# 3                  7/20/2022  Core Enchantment Zone
# 4                  8/28/2022           Stuart  Zone
# ...                      ...                    ...
# 36822              8/15/2022  Core Enchantment Zone
# 36823              7/27/2022  Core Enchantment Zone
# 36824              8/22/2022  Core Enchantment Zone
# 36825              8/26/2022  Core Enchantment Zone
# 36826              8/30/2022  Core Enchantment Zone
#
#        Minimum Acceptable Group Size 2  Maximum Requested Group Size 2  \
# 0                                  8.0                             8.0
# 1                                  2.0                             2.0
# 2                                  8.0                             8.0
# 3                                  2.0                             2.0
# 4                                  4.0                             4.0
# ...                                ...                             ...
# 36822                              3.0                             3.0
# 36823                              8.0                             8.0
# 36824                              4.0                             4.0
# 36825                              8.0                             8.0
# 36826                              8.0                             8.0
#
#       Preferred Entry Date 3   Preferred Division 3  \
# 0                  9/16/2022  Core Enchantment Zone
# 1                  8/29/2022          Colchuck Zone
# 2                   8/3/2022              Snow Zone
# 3                  7/13/2022              Snow Zone
# 4                  8/21/2022           Stuart  Zone
# ...                      ...                    ...
# 36822              8/22/2022  Core Enchantment Zone
# 36823               8/6/2022  Core Enchantment Zone
# 36824               8/2/2022  Core Enchantment Zone
# 36825               9/2/2022  Core Enchantment Zone
# 36826              8/31/2022  Core Enchantment Zone
#
#        Minimum Acceptable Group Size 3  Maximum Requested Group Size 3  \
# 0                                  8.0                             8.0
# 1                                  2.0                             2.0
# 2                                  8.0                             8.0
# 3                                  2.0                             2.0
# 4                                  4.0                             4.0
# ...                                ...                             ...
# 36822                              4.0                             4.0
# 36823                              8.0                             8.0
# 36824                              4.0                             4.0
# 36825                              8.0                             8.0
# 36826                              8.0                             8.0
#
#       Results Status  Awarded Preference Awarded Entry Date  \
# 0       Unsuccessful                 NaN                NaN
# 1       Unsuccessful                 NaN                NaN
# 2       Unsuccessful                 NaN                NaN
# 3       Unsuccessful                 NaN                NaN
# 4       Unsuccessful                 NaN                NaN
# ...              ...                 ...                ...
# 36822   Unsuccessful                 NaN                NaN
# 36823   Unsuccessful                 NaN                NaN
# 36824   Unsuccessful                 NaN                NaN
# 36825   Unsuccessful                 NaN                NaN
# 36826   Unsuccessful                 NaN                NaN
#
#       Awarded Entrance Code/Name  Awarded Group Size
# 0                            NaN                 NaN
# 1                            NaN                 NaN
# 2                            NaN                 NaN
# 3                            NaN                 NaN
# 4                            NaN                 NaN
# ...                          ...                 ...
# 36822                        NaN                 NaN
# 36823                        NaN                 NaN
# 36824                        NaN                 NaN
# 36825                        NaN                 NaN
# 36826                        NaN                 NaN
#
# [36827 rows x 17 columns]

# %%
df = df.drop(
    columns=[
        "Maximum Requested Group Size 1",
        "Maximum Requested Group Size 2",
        "Maximum Requested Group Size 3",
    ]
)
df = df.rename(
    columns={
        "Preferred Entry Date 1": "entry_date_1",
        "Preferred Division 1": "zone_1",
        "Minimum Acceptable Group Size 1": "group_size_1",
        "Preferred Entry Date 2": "entry_date_2",
        "Preferred Division 2": "zone_2",
        "Minimum Acceptable Group Size 2": "group_size_2",
        "Preferred Entry Date 3": "entry_date_3",
        "Preferred Division 3": "zone_3",
        "Minimum Acceptable Group Size 3": "group_size_3",
        "Results Status": "result",
        "Awarded Preference": "awarded_preference",
        "Awarded Entry Date": "awarded_entry_date",
        "Awarded Entrance Code/Name": "awarded_zone",
        "Awarded Group Size": "awarded_group_size",
    }
)
df
# Out:
#       entry_date_1                 zone_1  group_size_1 entry_date_2  \
# 0         9/2/2022  Core Enchantment Zone             8    8/26/2022
# 1        8/15/2022          Colchuck Zone             2    8/24/2022
# 2        8/12/2022              Snow Zone             8    8/19/2022
# 3        7/12/2022  Core Enchantment Zone             2    7/20/2022
# 4         9/3/2022           Stuart  Zone             4    8/28/2022
# ...            ...                    ...           ...          ...
# 36822    6/28/2022  Core Enchantment Zone             2    8/15/2022
# 36823     8/1/2022          Colchuck Zone             8    7/27/2022
# 36824    7/11/2022  Core Enchantment Zone             4    8/22/2022
# 36825    6/24/2022  Core Enchantment Zone             6    8/26/2022
# 36826    8/29/2022  Core Enchantment Zone             8    8/30/2022
#
#                       zone_2  group_size_2 entry_date_3  \
# 0              Colchuck Zone           8.0    9/16/2022
# 1              Colchuck Zone           2.0    8/29/2022
# 2                  Snow Zone           8.0     8/3/2022
# 3      Core Enchantment Zone           2.0    7/13/2022
# 4               Stuart  Zone           4.0    8/21/2022
# ...                      ...           ...          ...
# 36822  Core Enchantment Zone           3.0    8/22/2022
# 36823  Core Enchantment Zone           8.0     8/6/2022
# 36824  Core Enchantment Zone           4.0     8/2/2022
# 36825  Core Enchantment Zone           8.0     9/2/2022
# 36826  Core Enchantment Zone           8.0    8/31/2022
#
#                       zone_3  group_size_3        result  awarded_preference  \
# 0      Core Enchantment Zone           8.0  Unsuccessful                 NaN
# 1              Colchuck Zone           2.0  Unsuccessful                 NaN
# 2                  Snow Zone           8.0  Unsuccessful                 NaN
# 3                  Snow Zone           2.0  Unsuccessful                 NaN
# 4               Stuart  Zone           4.0  Unsuccessful                 NaN
# ...                      ...           ...           ...                 ...
# 36822  Core Enchantment Zone           4.0  Unsuccessful                 NaN
# 36823  Core Enchantment Zone           8.0  Unsuccessful                 NaN
# 36824  Core Enchantment Zone           4.0  Unsuccessful                 NaN
# 36825  Core Enchantment Zone           8.0  Unsuccessful                 NaN
# 36826  Core Enchantment Zone           8.0  Unsuccessful                 NaN
#
#       awarded_entry_date awarded_zone  awarded_group_size
# 0                    NaN          NaN                 NaN
# 1                    NaN          NaN                 NaN
# 2                    NaN          NaN                 NaN
# 3                    NaN          NaN                 NaN
# 4                    NaN          NaN                 NaN
# ...                  ...          ...                 ...
# 36822                NaN          NaN                 NaN
# 36823                NaN          NaN                 NaN
# 36824                NaN          NaN                 NaN
# 36825                NaN          NaN                 NaN
# 36826                NaN          NaN                 NaN
#
# [36827 rows x 14 columns]

# %%
def process_pref(df, i):
    # Just grab the columns for a specific preference
    df1 = df[
        [
            "entry_date_" + i,
            "zone_" + i,
            "group_size_" + i,
            "result",
            "awarded_preference",
        ]
    ]

    # Rename columns to match
    df1 = df1.rename(
        columns={
            "entry_date_" + i: "entry_date",
            "zone_" + i: "zone",
            "group_size_" + i: "group_size",
        }
    )

    # Only mark the status as successful if it was the selected preference
    df1.loc[df1["awarded_preference"] != int(i), "result"] = "Unsuccessful"
    
    # Mark as nan to remove requests after a successful one
    # df1.loc[df1["awarded_preference"] < int(i), "result"] = np.nan

    # Grab just the desired columns
    df1 = df1[["entry_date", "zone", "group_size", "result"]]

    # Remove na rows
    df1 = df1.dropna()
    
    df1 = df1.astype({"group_size": int})

    return df1

# Get the combined data
combined = pd.DataFrame([], columns = ["entry_date", "zone", "group_size", "result"])
for i in range(1, 4):
    temp = process_pref(df, str(i))
    combined = combined.append(temp)
    
combined = combined.reindex()

combined
# Out:
#       entry_date                   zone group_size        result
# 0       9/2/2022  Core Enchantment Zone          8  Unsuccessful
# 1      8/15/2022          Colchuck Zone          2  Unsuccessful
# 2      8/12/2022              Snow Zone          8  Unsuccessful
# 3      7/12/2022  Core Enchantment Zone          2  Unsuccessful
# 4       9/3/2022           Stuart  Zone          4  Unsuccessful
# ...          ...                    ...        ...           ...
# 36822  8/22/2022  Core Enchantment Zone          4  Unsuccessful
# 36823   8/6/2022  Core Enchantment Zone          8  Unsuccessful
# 36824   8/2/2022  Core Enchantment Zone          4  Unsuccessful
# 36825   9/2/2022  Core Enchantment Zone          8  Unsuccessful
# 36826  8/31/2022  Core Enchantment Zone          8  Unsuccessful
#
# [108810 rows x 4 columns]

# %%
# Write to csv
combined.to_csv("2022.csv", index=False)

# %%
by_zone = df.groupby("zone_1").agg({"entry_date_1": "count"}).reset_index()
by_zone = by_zone.rename(columns={"zone_1": "zone", "entry_date_1": "applications"})
by_zone.to_csv("2022_by_zone.csv", index=False)
by_zone
# Out:
#                               zone  applications
# 0                    Colchuck Zone          4606
# 1            Core Enchantment Zone         26988
# 2          Eightmile/Caroline Zone           548
# 3  Eightmile/Caroline Zone (stock)            50
# 4                        Snow Zone          2881
# 5                     Stuart  Zone          1713
# 6              Stuart Zone (stock)            41
